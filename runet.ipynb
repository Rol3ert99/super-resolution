# %% [markdown]
# # RUNet (Robust U-Net) implementation
# **Authors:** Konrad Maciejczyk (276927), Robert Walery (24900)
# Wrocław University of Science and Technology, 2023-2024
#
# Dataset: [*STL-10 Image Recognition Dataset*](https://www.kaggle.com/datasets/jessicali9530/stl10?resource=download)
# Reference paper: Hu, Xiaodan, et al. [*RUNet: A Robust UNet Architecture for Image Super-Resolution*](https://openaccess.thecvf.com/content_CVPRW_2019/papers/WiCV/Hu_RUNet_A_Robust_UNet_Architecture_for_Image_Super-Resolution_CVPRW_2019_paper.pdf)
#
# ---

# %%
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import cv2
import datetime

if len(tf.config.list_physical_devices('GPU')) < 1:
  raise Exception("GPU device not found!")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/DATA/stl_10.zip

# %% [markdown]
# ## Data loading and data preprocessing
# For our needs the training data is descaled half of it's original size (from 96x96 to 46x46).
# The dataset is splitted into training data (80% - 4000 images) and testing data (20% - 1000 images).

# %%
input_folder = "./train_images/"
image_files = [f for f in os.listdir(input_folder) if f.endswith(".png") or f.endswith(".jpg")]
images_Y = [cv2.imread(os.path.join(input_folder, img)) for img in image_files]
images_X = [cv2.resize(img, (48, 48), interpolation=cv2.INTER_AREA) for img in images_Y]
images_X = [img / 255.0 for img in images_X]
images_Y_ = [img / 255.0 for img in images_Y]
images_X = np.array(images_X)
images_Y = np.array(images_Y)
X_train, X_test, Y_train, Y_test = train_test_split(images_X, images_Y, test_size=0.2, random_state=42)

input_size = 48
print(X_train.shape)
print(Y_test.shape)
print(type(X_train))
# Out:
# (1600, 48, 48, 3)
# (400, 96, 96, 3)
# <class 'numpy.ndarray'>

# %% [markdown]
# ## RUNet architecture
# ### Auxiliary functions for repetetive fragments

# %%
# pixel shuffle
def pixel_shuffle(scale):
    if scale > 1:
        return lambda x: tf.nn.depth_to_space(x, scale)
    else:
        return lambda x:x

def insert_downsampling_block(x_inp, filters, kernel_size=(3, 3), padding="same", strides=1,r=False):
    x = tf.keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(x_inp)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    if r:
        x_inp = tf.keras.layers.Conv2D(filters,(1,1), padding=padding, strides=strides)(x_inp)
    x = tf.keras.layers.Add()([x,x_inp])
    return x

def insert_bottleneck(x_inp,filters, kernel_size=(3, 3), padding="same", strides=1):
    x = tf.keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(x_inp)
    x = tf.keras.layers.Activation('relu')(x)
    return x

def insert_upscaling_block(x_inp,skip,filters, kernel_size=(3, 3), padding="same", strides=1,upscale_factor=2):
    x = pixel_shuffle(scale=upscale_factor)(x_inp)
    x = tf.keras.layers.Concatenate()([x, skip])
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
input = tf.keras.layers.Input(shape = (input_size, input_size, 3))
down_1 = tf.keras.layers.Conv2D(64,(7,7), padding="same", strides=1)(input)
down_1 = tf.keras.layers.BatchNormalization()(down_1)
down_1 = tf.keras.layers.Activation('relu')(down_1)

down_2 = tf.keras.layers.MaxPool2D(pool_size=(2,2))(down_1)
down_2 = insert_downsampling_block(down_2, 64)
down_2 = insert_downsampling_block(down_2, 64)
down_2 = insert_downsampling_block(down_2, 64)
down_2 = insert_downsampling_block(down_2, 128, r=True)

down_3 = tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=2)(down_2)
down_3 = insert_downsampling_block(down_3, 128)
down_3 = insert_downsampling_block(down_3, 128)
down_3 = insert_downsampling_block(down_3, 128)
down_3 = insert_downsampling_block(down_3, 256, r=True)

down_4 = tf.keras.layers.MaxPool2D(pool_size=(2, 2))(down_3)
down_4 = insert_downsampling_block(down_4,256)
down_4 = insert_downsampling_block(down_4,256)
down_4 = insert_downsampling_block(down_4,256)
down_4 = insert_downsampling_block(down_4,256)
down_4 = insert_downsampling_block(down_4,256)
down_4 = insert_downsampling_block(down_4,512,r=True)

down_5 = tf.keras.layers.MaxPool2D(pool_size=(2, 2))(down_4)
down_5 = insert_downsampling_block(down_5,512)
down_5 = insert_downsampling_block(down_5,512)
down_5 = tf.keras.layers.BatchNormalization()(down_5)
down_5 = tf.keras.layers.Activation('relu')(down_5)

bn_1 = insert_bottleneck(down_5, 1024)
bn_2 = insert_bottleneck(bn_1, 512)

up_1 = insert_upscaling_block(bn_2,down_5, 512,upscale_factor=1)
up_2 = insert_upscaling_block(up_1,down_4, 384,upscale_factor=2)
up_3 = insert_upscaling_block(up_2,down_3, 256,upscale_factor=2)
up_4 = insert_upscaling_block(up_3,down_2, 96,upscale_factor=2)

up_5 = pixel_shuffle(scale=2)(up_4)
up_5 = tf.keras.layers.Concatenate()([up_5,down_1])
up_5 = tf.keras.layers.Conv2D(99,(3,3), padding="same", strides=1)(up_5)
up_5 = tf.keras.layers.Activation('relu')(up_5)
up_5 = tf.keras.layers.Conv2D(99,(3,3), padding="same", strides=1)(up_5)
up_5 = tf.keras.layers.Activation('relu')(up_5)

up_conv4 = tf.keras.layers.Conv2DTranspose(filters=32, kernel_size=(2,2), strides=(2,2), padding='same')(up_5)
conv8_1 = tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(up_conv4)
conv8_2 = tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', padding='same')(conv8_1)

output = tf.keras.layers.Conv2D(3,(1,1), padding="same")(conv8_2)
model = tf.keras.models.Model(input, output)
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 48, 48, 3)]          0         []
#
#  conv2d_419 (Conv2D)         (None, 48, 48, 64)           9472      ['input_11[0][0]']
#
#  batch_normalization_335 (B  (None, 48, 48, 64)           256       ['conv2d_419[0][0]']
#  atchNormalization)
#
#  activation_279 (Activation  (None, 48, 48, 64)           0         ['batch_normalization_335[0][0
#  )                                                                  ]']
#
#  max_pooling2d_36 (MaxPooli  (None, 24, 24, 64)           0         ['activation_279[0][0]']
#  ng2D)
#
#  conv2d_420 (Conv2D)         (None, 24, 24, 64)           36928     ['max_pooling2d_36[0][0]']
#
#  batch_normalization_336 (B  (None, 24, 24, 64)           256       ['conv2d_420[0][0]']
#  atchNormalization)
#
#  activation_280 (Activation  (None, 24, 24, 64)           0         ['batch_normalization_336[0][0
#  )                                                                  ]']
#
#  conv2d_421 (Conv2D)         (None, 24, 24, 64)           36928     ['activation_280[0][0]']
#
#  batch_normalization_337 (B  (None, 24, 24, 64)           256       ['conv2d_421[0][0]']
#  atchNormalization)
#
#  add_144 (Add)               (None, 24, 24, 64)           0         ['batch_normalization_337[0][0
#                                                                     ]',
#                                                                      'max_pooling2d_36[0][0]']
#
#  conv2d_422 (Conv2D)         (None, 24, 24, 64)           36928     ['add_144[0][0]']
#
#  batch_normalization_338 (B  (None, 24, 24, 64)           256       ['conv2d_422[0][0]']
#  atchNormalization)
#
#  activation_281 (Activation  (None, 24, 24, 64)           0         ['batch_normalization_338[0][0
#  )                                                                  ]']
#
#  conv2d_423 (Conv2D)         (None, 24, 24, 64)           36928     ['activation_281[0][0]']
#
#  batch_normalization_339 (B  (None, 24, 24, 64)           256       ['conv2d_423[0][0]']
#  atchNormalization)
#
#  add_145 (Add)               (None, 24, 24, 64)           0         ['batch_normalization_339[0][0
#                                                                     ]',
#                                                                      'add_144[0][0]']
#
#  conv2d_424 (Conv2D)         (None, 24, 24, 64)           36928     ['add_145[0][0]']
#
#  batch_normalization_340 (B  (None, 24, 24, 64)           256       ['conv2d_424[0][0]']
#  atchNormalization)
#
#  activation_282 (Activation  (None, 24, 24, 64)           0         ['batch_normalization_340[0][0
#  )                                                                  ]']
#
#  conv2d_425 (Conv2D)         (None, 24, 24, 64)           36928     ['activation_282[0][0]']
#
#  batch_normalization_341 (B  (None, 24, 24, 64)           256       ['conv2d_425[0][0]']
#  atchNormalization)
#
#  add_146 (Add)               (None, 24, 24, 64)           0         ['batch_normalization_341[0][0
#                                                                     ]',
#                                                                      'add_145[0][0]']
#
#  conv2d_426 (Conv2D)         (None, 24, 24, 128)          73856     ['add_146[0][0]']
#
#  batch_normalization_342 (B  (None, 24, 24, 128)          512       ['conv2d_426[0][0]']
#  atchNormalization)
#
#  activation_283 (Activation  (None, 24, 24, 128)          0         ['batch_normalization_342[0][0
#  )                                                                  ]']
#
#  conv2d_427 (Conv2D)         (None, 24, 24, 128)          147584    ['activation_283[0][0]']
#
#  batch_normalization_343 (B  (None, 24, 24, 128)          512       ['conv2d_427[0][0]']
#  atchNormalization)
#
#  conv2d_428 (Conv2D)         (None, 24, 24, 128)          8320      ['add_146[0][0]']
#
#  add_147 (Add)               (None, 24, 24, 128)          0         ['batch_normalization_343[0][0
#                                                                     ]',
#                                                                      'conv2d_428[0][0]']
#
#  max_pooling2d_37 (MaxPooli  (None, 12, 12, 128)          0         ['add_147[0][0]']
#  ng2D)
#
#  conv2d_429 (Conv2D)         (None, 12, 12, 128)          147584    ['max_pooling2d_37[0][0]']
#
#  batch_normalization_344 (B  (None, 12, 12, 128)          512       ['conv2d_429[0][0]']
#  atchNormalization)
#
#  activation_284 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_344[0][0
#  )                                                                  ]']
#
#  conv2d_430 (Conv2D)         (None, 12, 12, 128)          147584    ['activation_284[0][0]']
#
#  batch_normalization_345 (B  (None, 12, 12, 128)          512       ['conv2d_430[0][0]']
#  atchNormalization)
#
#  add_148 (Add)               (None, 12, 12, 128)          0         ['batch_normalization_345[0][0
#                                                                     ]',
#                                                                      'max_pooling2d_37[0][0]']
#
#  conv2d_431 (Conv2D)         (None, 12, 12, 128)          147584    ['add_148[0][0]']
#
#  batch_normalization_346 (B  (None, 12, 12, 128)          512       ['conv2d_431[0][0]']
#  atchNormalization)
#
#  activation_285 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_346[0][0
#  )                                                                  ]']
#
#  conv2d_432 (Conv2D)         (None, 12, 12, 128)          147584    ['activation_285[0][0]']
#
#  batch_normalization_347 (B  (None, 12, 12, 128)          512       ['conv2d_432[0][0]']
#  atchNormalization)
#
#  add_149 (Add)               (None, 12, 12, 128)          0         ['batch_normalization_347[0][0
#                                                                     ]',
#                                                                      'add_148[0][0]']
#
#  conv2d_433 (Conv2D)         (None, 12, 12, 128)          147584    ['add_149[0][0]']
#
#  batch_normalization_348 (B  (None, 12, 12, 128)          512       ['conv2d_433[0][0]']
#  atchNormalization)
#
#  activation_286 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_348[0][0
#  )                                                                  ]']
#
#  conv2d_434 (Conv2D)         (None, 12, 12, 128)          147584    ['activation_286[0][0]']
#
#  batch_normalization_349 (B  (None, 12, 12, 128)          512       ['conv2d_434[0][0]']
#  atchNormalization)
#
#  add_150 (Add)               (None, 12, 12, 128)          0         ['batch_normalization_349[0][0
#                                                                     ]',
#                                                                      'add_149[0][0]']
#
#  conv2d_435 (Conv2D)         (None, 12, 12, 256)          295168    ['add_150[0][0]']
#
#  batch_normalization_350 (B  (None, 12, 12, 256)          1024      ['conv2d_435[0][0]']
#  atchNormalization)
#
#  activation_287 (Activation  (None, 12, 12, 256)          0         ['batch_normalization_350[0][0
#  )                                                                  ]']
#
#  conv2d_436 (Conv2D)         (None, 12, 12, 256)          590080    ['activation_287[0][0]']
#
#  batch_normalization_351 (B  (None, 12, 12, 256)          1024      ['conv2d_436[0][0]']
#  atchNormalization)
#
#  conv2d_437 (Conv2D)         (None, 12, 12, 256)          33024     ['add_150[0][0]']
#
#  add_151 (Add)               (None, 12, 12, 256)          0         ['batch_normalization_351[0][0
#                                                                     ]',
#                                                                      'conv2d_437[0][0]']
#
#  max_pooling2d_38 (MaxPooli  (None, 6, 6, 256)            0         ['add_151[0][0]']
#  ng2D)
#
#  conv2d_438 (Conv2D)         (None, 6, 6, 256)            590080    ['max_pooling2d_38[0][0]']
#
#  batch_normalization_352 (B  (None, 6, 6, 256)            1024      ['conv2d_438[0][0]']
#  atchNormalization)
#
#  activation_288 (Activation  (None, 6, 6, 256)            0         ['batch_normalization_352[0][0
#  )                                                                  ]']
#
#  conv2d_439 (Conv2D)         (None, 6, 6, 256)            590080    ['activation_288[0][0]']
#
#  batch_normalization_353 (B  (None, 6, 6, 256)            1024      ['conv2d_439[0][0]']
#  atchNormalization)
#
#  add_152 (Add)               (None, 6, 6, 256)            0         ['batch_normalization_353[0][0
#                                                                     ]',
#                                                                      'max_pooling2d_38[0][0]']
#
#  conv2d_440 (Conv2D)         (None, 6, 6, 256)            590080    ['add_152[0][0]']
#
#  batch_normalization_354 (B  (None, 6, 6, 256)            1024      ['conv2d_440[0][0]']
#  atchNormalization)
#
#  activation_289 (Activation  (None, 6, 6, 256)            0         ['batch_normalization_354[0][0
#  )                                                                  ]']
#
#  conv2d_441 (Conv2D)         (None, 6, 6, 256)            590080    ['activation_289[0][0]']
#
#  batch_normalization_355 (B  (None, 6, 6, 256)            1024      ['conv2d_441[0][0]']
#  atchNormalization)
#
#  add_153 (Add)               (None, 6, 6, 256)            0         ['batch_normalization_355[0][0
#                                                                     ]',
#                                                                      'add_152[0][0]']
#
#  conv2d_442 (Conv2D)         (None, 6, 6, 256)            590080    ['add_153[0][0]']
#
#  batch_normalization_356 (B  (None, 6, 6, 256)            1024      ['conv2d_442[0][0]']
#  atchNormalization)
#
#  activation_290 (Activation  (None, 6, 6, 256)            0         ['batch_normalization_356[0][0
#  )                                                                  ]']
#
#  conv2d_443 (Conv2D)         (None, 6, 6, 256)            590080    ['activation_290[0][0]']
#
#  batch_normalization_357 (B  (None, 6, 6, 256)            1024      ['conv2d_443[0][0]']
#  atchNormalization)
#
#  add_154 (Add)               (None, 6, 6, 256)            0         ['batch_normalization_357[0][0
#                                                                     ]',
#                                                                      'add_153[0][0]']
#
#  conv2d_444 (Conv2D)         (None, 6, 6, 256)            590080    ['add_154[0][0]']
#
#  batch_normalization_358 (B  (None, 6, 6, 256)            1024      ['conv2d_444[0][0]']
#  atchNormalization)
#
#  activation_291 (Activation  (None, 6, 6, 256)            0         ['batch_normalization_358[0][0
#  )                                                                  ]']
#
#  conv2d_445 (Conv2D)         (None, 6, 6, 256)            590080    ['activation_291[0][0]']
#
#  batch_normalization_359 (B  (None, 6, 6, 256)            1024      ['conv2d_445[0][0]']
#  atchNormalization)
#
#  add_155 (Add)               (None, 6, 6, 256)            0         ['batch_normalization_359[0][0
#                                                                     ]',
#                                                                      'add_154[0][0]']
#
#  conv2d_446 (Conv2D)         (None, 6, 6, 256)            590080    ['add_155[0][0]']
#
#  batch_normalization_360 (B  (None, 6, 6, 256)            1024      ['conv2d_446[0][0]']
#  atchNormalization)
#
#  activation_292 (Activation  (None, 6, 6, 256)            0         ['batch_normalization_360[0][0
#  )                                                                  ]']
#
#  conv2d_447 (Conv2D)         (None, 6, 6, 256)            590080    ['activation_292[0][0]']
#
#  batch_normalization_361 (B  (None, 6, 6, 256)            1024      ['conv2d_447[0][0]']
#  atchNormalization)
#
#  add_156 (Add)               (None, 6, 6, 256)            0         ['batch_normalization_361[0][0
#                                                                     ]',
#                                                                      'add_155[0][0]']
#
#  conv2d_448 (Conv2D)         (None, 6, 6, 512)            1180160   ['add_156[0][0]']
#
#  batch_normalization_362 (B  (None, 6, 6, 512)            2048      ['conv2d_448[0][0]']
#  atchNormalization)
#
#  activation_293 (Activation  (None, 6, 6, 512)            0         ['batch_normalization_362[0][0
#  )                                                                  ]']
#
#  conv2d_449 (Conv2D)         (None, 6, 6, 512)            2359808   ['activation_293[0][0]']
#
#  batch_normalization_363 (B  (None, 6, 6, 512)            2048      ['conv2d_449[0][0]']
#  atchNormalization)
#
#  conv2d_450 (Conv2D)         (None, 6, 6, 512)            131584    ['add_156[0][0]']
#
#  add_157 (Add)               (None, 6, 6, 512)            0         ['batch_normalization_363[0][0
#                                                                     ]',
#                                                                      'conv2d_450[0][0]']
#
#  max_pooling2d_39 (MaxPooli  (None, 3, 3, 512)            0         ['add_157[0][0]']
#  ng2D)
#
#  conv2d_451 (Conv2D)         (None, 3, 3, 512)            2359808   ['max_pooling2d_39[0][0]']
#
#  batch_normalization_364 (B  (None, 3, 3, 512)            2048      ['conv2d_451[0][0]']
#  atchNormalization)
#
#  activation_294 (Activation  (None, 3, 3, 512)            0         ['batch_normalization_364[0][0
#  )                                                                  ]']
#
#  conv2d_452 (Conv2D)         (None, 3, 3, 512)            2359808   ['activation_294[0][0]']
#
#  batch_normalization_365 (B  (None, 3, 3, 512)            2048      ['conv2d_452[0][0]']
#  atchNormalization)
#
#  add_158 (Add)               (None, 3, 3, 512)            0         ['batch_normalization_365[0][0
#                                                                     ]',
#                                                                      'max_pooling2d_39[0][0]']
#
#  conv2d_453 (Conv2D)         (None, 3, 3, 512)            2359808   ['add_158[0][0]']
#
#  batch_normalization_366 (B  (None, 3, 3, 512)            2048      ['conv2d_453[0][0]']
#  atchNormalization)
#
#  activation_295 (Activation  (None, 3, 3, 512)            0         ['batch_normalization_366[0][0
#  )                                                                  ]']
#
#  conv2d_454 (Conv2D)         (None, 3, 3, 512)            2359808   ['activation_295[0][0]']
#
#  batch_normalization_367 (B  (None, 3, 3, 512)            2048      ['conv2d_454[0][0]']
#  atchNormalization)
#
#  add_159 (Add)               (None, 3, 3, 512)            0         ['batch_normalization_367[0][0
#                                                                     ]',
#                                                                      'add_158[0][0]']
#
#  batch_normalization_368 (B  (None, 3, 3, 512)            2048      ['add_159[0][0]']
#  atchNormalization)
#
#  activation_296 (Activation  (None, 3, 3, 512)            0         ['batch_normalization_368[0][0
#  )                                                                  ]']
#
#  conv2d_455 (Conv2D)         (None, 3, 3, 1024)           4719616   ['activation_296[0][0]']
#
#  activation_297 (Activation  (None, 3, 3, 1024)           0         ['conv2d_455[0][0]']
#  )
#
#  conv2d_456 (Conv2D)         (None, 3, 3, 512)            4719104   ['activation_297[0][0]']
#
#  activation_298 (Activation  (None, 3, 3, 512)            0         ['conv2d_456[0][0]']
#  )
#
#  concatenate_38 (Concatenat  (None, 3, 3, 1024)           0         ['activation_298[0][0]',
#  e)                                                                  'activation_296[0][0]']
#
#  batch_normalization_369 (B  (None, 3, 3, 1024)           4096      ['concatenate_38[0][0]']
#  atchNormalization)
#
#  conv2d_457 (Conv2D)         (None, 3, 3, 512)            4719104   ['batch_normalization_369[0][0
#                                                                     ]']
#
#  activation_299 (Activation  (None, 3, 3, 512)            0         ['conv2d_457[0][0]']
#  )
#
#  conv2d_458 (Conv2D)         (None, 3, 3, 512)            2359808   ['activation_299[0][0]']
#
#  activation_300 (Activation  (None, 3, 3, 512)            0         ['conv2d_458[0][0]']
#  )
#
#  activation_301 (Activation  (None, 3, 3, 512)            0         ['activation_300[0][0]']
#  )
#
#  tf.nn.depth_to_space_29 (T  (None, 6, 6, 128)            0         ['activation_301[0][0]']
#  FOpLambda)
#
#  concatenate_39 (Concatenat  (None, 6, 6, 640)            0         ['tf.nn.depth_to_space_29[0][0
#  e)                                                                 ]',
#                                                                      'add_157[0][0]']
#
#  batch_normalization_370 (B  (None, 6, 6, 640)            2560      ['concatenate_39[0][0]']
#  atchNormalization)
#
#  conv2d_459 (Conv2D)         (None, 6, 6, 384)            2212224   ['batch_normalization_370[0][0
#                                                                     ]']
#
#  activation_302 (Activation  (None, 6, 6, 384)            0         ['conv2d_459[0][0]']
#  )
#
#  conv2d_460 (Conv2D)         (None, 6, 6, 384)            1327488   ['activation_302[0][0]']
#
#  activation_303 (Activation  (None, 6, 6, 384)            0         ['conv2d_460[0][0]']
#  )
#
#  activation_304 (Activation  (None, 6, 6, 384)            0         ['activation_303[0][0]']
#  )
#
#  tf.nn.depth_to_space_30 (T  (None, 12, 12, 96)           0         ['activation_304[0][0]']
#  FOpLambda)
#
#  concatenate_40 (Concatenat  (None, 12, 12, 352)          0         ['tf.nn.depth_to_space_30[0][0
#  e)                                                                 ]',
#                                                                      'add_151[0][0]']
#
#  batch_normalization_371 (B  (None, 12, 12, 352)          1408      ['concatenate_40[0][0]']
#  atchNormalization)
#
#  conv2d_461 (Conv2D)         (None, 12, 12, 256)          811264    ['batch_normalization_371[0][0
#                                                                     ]']
#
#  activation_305 (Activation  (None, 12, 12, 256)          0         ['conv2d_461[0][0]']
#  )
#
#  conv2d_462 (Conv2D)         (None, 12, 12, 256)          590080    ['activation_305[0][0]']
#
#  activation_306 (Activation  (None, 12, 12, 256)          0         ['conv2d_462[0][0]']
#  )
#
#  activation_307 (Activation  (None, 12, 12, 256)          0         ['activation_306[0][0]']
#  )
#
#  tf.nn.depth_to_space_31 (T  (None, 24, 24, 64)           0         ['activation_307[0][0]']
#  FOpLambda)
#
#  concatenate_41 (Concatenat  (None, 24, 24, 192)          0         ['tf.nn.depth_to_space_31[0][0
#  e)                                                                 ]',
#                                                                      'add_147[0][0]']
#
#  batch_normalization_372 (B  (None, 24, 24, 192)          768       ['concatenate_41[0][0]']
#  atchNormalization)
#
#  conv2d_463 (Conv2D)         (None, 24, 24, 96)           165984    ['batch_normalization_372[0][0
#                                                                     ]']
#
#  activation_308 (Activation  (None, 24, 24, 96)           0         ['conv2d_463[0][0]']
#  )
#
#  conv2d_464 (Conv2D)         (None, 24, 24, 96)           83040     ['activation_308[0][0]']
#
#  activation_309 (Activation  (None, 24, 24, 96)           0         ['conv2d_464[0][0]']
#  )
#
#  activation_310 (Activation  (None, 24, 24, 96)           0         ['activation_309[0][0]']
#  )
#
#  tf.nn.depth_to_space_32 (T  (None, 48, 48, 24)           0         ['activation_310[0][0]']
#  FOpLambda)
#
#  concatenate_42 (Concatenat  (None, 48, 48, 88)           0         ['tf.nn.depth_to_space_32[0][0
#  e)                                                                 ]',
#                                                                      'activation_279[0][0]']
#
#  conv2d_465 (Conv2D)         (None, 48, 48, 99)           78507     ['concatenate_42[0][0]']
#
#  activation_311 (Activation  (None, 48, 48, 99)           0         ['conv2d_465[0][0]']
#  )
#
#  conv2d_466 (Conv2D)         (None, 48, 48, 99)           88308     ['activation_311[0][0]']
#
#  activation_312 (Activation  (None, 48, 48, 99)           0         ['conv2d_466[0][0]']
#  )
#
#  conv2d_transpose_1 (Conv2D  (None, 96, 96, 32)           12704     ['activation_312[0][0]']
#  Transpose)
#
#  conv2d_467 (Conv2D)         (None, 96, 96, 32)           9248      ['conv2d_transpose_1[0][0]']
#
#  conv2d_468 (Conv2D)         (None, 96, 96, 32)           9248      ['conv2d_467[0][0]']
#
#  conv2d_469 (Conv2D)         (None, 96, 96, 3)            99        ['conv2d_468[0][0]']
#
# ==================================================================================================
# Total params: 43223330 (164.88 MB)
# Trainable params: 43202658 (164.81 MB)
# Non-trainable params: 20672 (80.75 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Metrics used as loss functions
# **PSNR** - In image evaluation, PSNR (Peak Signal-to-Noise Ratio) quantifies the ratio between the maximum possible power of the image and the noise introduced during compression, giving an indication of how closely the reconstructed image matches the original in terms of fidelity.
#
# **SSIM** - SSIM stands for Structural Similarity Index Measure. It's a metric used to evaluate the similarity between two images, measuring not just the resemblance in pixel values but also accounting for perceived changes in structural information, luminance, and contrast. SSIM assesses the similarity in structure by considering local patterns in the images and human visual perception characteristics, providing a more comprehensive assessment of image quality than traditional pixel-based metrics.

# %%
def psnr(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

def ssim(y_true,y_pred):
    return tf.image.ssim(y_true,y_pred,1.0)

# %%
opt = tf.keras.optimizers.Adam(learning_rate = 0.001)
model.compile(optimizer='adam', loss='mean_squared_error', metrics=[psnr, ssim])

# %%
model.fit(X_train, Y_train, epochs=50, batch_size=128, validation_split=0.2)

timestamp = datetime.datetime.now()
model.save(f'{timestamp.day}_{timestamp.month}__{timestamp.hour}_{timestamp.minute}.h5')
# Out:
# 10/10 [==============================] - 4s 439ms/step - loss: 220.6476 - psnr: -22.9478 - val_loss: 240.2100 - val_psnr: -23.3955

# %%
# !mv ./TEST /content/drive/MyDrive/
